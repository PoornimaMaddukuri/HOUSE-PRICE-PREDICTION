# %% [raw]
# HOUSE PRICE PREDICTION

# %%
import pandas as pd

# %%
df = pd.read_csv("house.csv", delimiter="\t")

# %%
df
# Out:
#    area_sqft,bedrooms,area_type,price
# 0                4619,2,Urban,2672199
# 1                3126,3,Urban,2672202
# 2                2419,2,Rural,2672205
# 3                2122,2,Urban,2672208
# 4                4069,2,Urban,2394930
# ..                                ...
# 95               3022,2,Rural,1723275
# 96               4293,5,Urban,2906577
# 97               2665,3,Rural,1564122
# 98               2734,4,Rural,1898025
# 99               4743,3,Rural,2525649
#
# [100 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Re-read the CSV with the correct delimiter
df = pd.read_csv("house.csv", delimiter=",")

# Encode 'area_type' to numeric
le = LabelEncoder()
df["area_type"] = le.fit_transform(df["area_type"])  # Urban=1, Rural=0

# Now you can safely train the model
X = df[["area_sqft", "bedrooms", "area_type"]]
y = df["price"]

# %%
x=df[["area_sqft","bedrooms","area_type"]]

# %%
x
# Out:
#     area_sqft  bedrooms  area_type
# 0        4619         2          1
# 1        3126         3          1
# 2        2419         2          0
# 3        2122         2          1
# 4        4069         2          1
# ..        ...       ...        ...
# 95       3022         2          0
# 96       4293         5          1
# 97       2665         3          0
# 98       2734         4          0
# 99       4743         3          0
#
# [100 rows x 3 columns]

# %%
y=df.price

# %%
y
# Out:
# 0     2672199
# 1     2672202
# 2     2672205
# 3     2672208
# 4     2394930
#        ...
# 95    1723275
# 96    2906577
# 97    1564122
# 98    1898025
# 99    2525649
# Name: price, Length: 100, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([   432.24558291, 122787.20546704, 239834.78150204])

# %%
model.intercept_
# Out:
# 163488.79581670882

# %%
model.predict([[5000,3,5]])
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3892252.23427306])

# %%
df
# Out:
#     area_sqft  bedrooms  area_type    price
# 0        4619         2          1  2672199
# 1        3126         3          1  2672202
# 2        2419         2          0  2672205
# 3        2122         2          1  2672208
# 4        4069         2          1  2394930
# ..        ...       ...        ...      ...
# 95       3022         2          0  1723275
# 96       4293         5          1  2906577
# 97       2665         3          0  1564122
# 98       2734         4          0  1898025
# 99       4743         3          0  2525649
#
# [100 rows x 4 columns]
